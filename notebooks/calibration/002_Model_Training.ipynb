# %%
# Import utilities from src modules
import sys
from pathlib import Path
PROJECT_ROOT = Path().resolve().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))
# %cd $PROJECT_ROOT


from src.config import (
    POLE_DETECTION_CONFIG,
    RULER_DETECTION_CONFIG,
    POLE_TOP_DETECTION_CONFIG,
    RULER_MARKING_DETECTION_CONFIG,
)
# Out:
# /home/saroj/Desktop/Python_Projects/Pole_Annotation

# %%
# %load_ext tensorboard
# %tensorboard --logdir=runs

# %%
# Train Pole Detection Model
# !python train.py --model pole_detection --epochs {POLE_DETECTION_CONFIG['epochs']} --batch-size {POLE_DETECTION_CONFIG['batch_size']}

# %%
# Train Ruler Detection Model
# !python train.py --model ruler_detection --epochs {RULER_DETECTION_CONFIG['epochs']} --batch-size {RULER_DETECTION_CONFIG['batch_size']}

# %%
# Train Pole Top Detection Model
# !python train.py --model pole_top_detection --epochs {POLE_TOP_DETECTION_CONFIG['epochs']} --batch-size {POLE_TOP_DETECTION_CONFIG['batch_size']}
# Out:
# 2026-02-22 22:12:52,698 - __main__ - INFO - Training started for model: pole_top_detection
# 2026-02-22 22:12:52,698 - __main__ - INFO - Log file: logs/train_pole_top_detection_20260222_221252.log
# 2026-02-22 22:12:52,698 - __main__ - INFO - Arguments: {'model': 'pole_top_detection', 'epochs': 100, 'batch_size': 96, 'lr': None, 'device': 'auto', 'resume': False, 'warm_start': False, 'debug': False, 'dry_run': False, 'clear_cache': False}
# 2026-02-22 22:12:52,698 - __main__ - INFO - Model: pole_top_detection
# 2026-02-22 22:12:52,698 - __main__ - INFO - Training function: train_pole_top_detector
# 2026-02-22 22:12:52,698 - __main__ - INFO - Hyperparameters: {'train_dir': '/home/saroj/Desktop/Python_Projects/Pole_Annotation/datasets/pole_top_detection', 'epochs': 100, 'batch_size': 96, 'resume': False}
# 2026-02-22 22:12:52,698 - __main__ - INFO - 🚀 Starting training for pole_top_detection...
# PoleTopKeypointDataset: 12206 images (upper 10% crop)
# ...

# %%
# Train Ruler Marking Detection Model
# !python train.py --model ruler_marking_detection --epochs {RULER_MARKING_DETECTION_CONFIG['epochs']} --batch-size {RULER_MARKING_DETECTION_CONFIG['batch_size']}
