# %% [markdown]
# # Vizualize Raw Data

# %%
# Import utilities from src modules
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent.parent))

from src.config import KEYPOINT_NAMES, DATASETS_DIR

from src.data_utils import parse_label_file, check_dataset_complete, keypoint_in_bbox
from src.visualization import parse_yolo_label, parse_keypoint_label, visualize_sample

print('All modules imported successfully!')
# Out:
# All modules imported successfully!

# %%
# Data Visualization: Pole and Midspan Images (centralized viz + config colors)
from src.config import BASE_DIR_POLE, BASE_DIR_MIDSPAN, POLE_LABELS_DIR, MIDSPAN_LABELS_DIR
from src.visualization import visualize_pole_and_midspan_images

pole_photos_dir = BASE_DIR_POLE / "Photos"
pole_labels_dir = POLE_LABELS_DIR
midspan_photos_dir = BASE_DIR_MIDSPAN / "Photos"
midspan_labels_dir = MIDSPAN_LABELS_DIR

visualize_pole_and_midspan_images(pole_photos_dir, pole_labels_dir,
                                  midspan_photos_dir, midspan_labels_dir)

# %% [markdown]
# # Vizualize Prepared Dataset

# %%
# Visualize samples from each dataset (centralized viz + VIZ_FIG_DEFAULTS)
from src.visualization import visualize_dataset_samples_grid
from src.config import VISUALIZATION_DATASETS_CONFIG

visualize_dataset_samples_grid(VISUALIZATION_DATASETS_CONFIG)
print("\n✓ Visualization complete!")
# Out:
# ✓ Visualization complete!
