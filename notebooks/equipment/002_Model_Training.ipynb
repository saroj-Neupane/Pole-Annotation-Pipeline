# %%
# Import utilities and change to project root (so !python train.py works)
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent.parent
sys.path.insert(0, str(PROJECT_ROOT))
# %cd $PROJECT_ROOT
import matplotlib.pyplot as plt
from src.config import (
    RISER_KEYPOINT_DETECTION_CONFIG,
    TRANSFORMER_KEYPOINT_DETECTION_CONFIG,
    STREET_LIGHT_KEYPOINT_DETECTION_CONFIG,
    EQUIPMENT_DETECTION_CONFIG
)

# %%
# Train equipment detection (Riser, Transformer, Street Light, Secondary Drip Loop)
# !python train.py --model equipment_detection

# %%
# Train HRNet on the prepared Transformer Keypoint Detection Dataset
from src.config import TRANSFORMER_KEYPOINT_DETECTION_CONFIG

# !python train.py --model transformer_keypoint_detection

# %%
# Train HRNet on the prepared Street Light Keypoint Detection Dataset
from src.config import STREET_LIGHT_KEYPOINT_DETECTION_CONFIG

# !python train.py --model street_light_keypoint_detection

# %%
# Train HRNet on the prepared Riser Keypoint Detection Dataset
from src.config import RISER_KEYPOINT_DETECTION_CONFIG

# !python train.py --model riser_keypoint_detection

# %%
# Train HRNet on the prepared secondary drip loop Keypoint Detection Dataset
from src.config import SECONDARY_DRIP_LOOP_KEYPOINT_DETECTION_CONFIG

# !python train.py --model secondary_drip_loop_keypoint_detection
